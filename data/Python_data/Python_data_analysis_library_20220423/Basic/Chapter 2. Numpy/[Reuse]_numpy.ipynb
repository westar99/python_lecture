# %% [markdown]
# # NumPy 기본 문법

# %% [markdown]
# ## 리스트를 NumPy로 변환하기
# - 먼저 라이브러리를 불러온다.

# %%
#

# %% [markdown]
# - 1부터 10까지의 리스트를 만든 후 NumPy 배열로 변환하여 저장한다.

# %%
#

# %% [markdown]
# - type(), len() 함수를 사용하여 배열의 기본 정보를 확인한다.

# %%
#
# Out:
# numpy.ndarray

# %%
#
# Out:
# 10

# %% [markdown]
# - 첫번째 인수 1을 출력한다.

# %%
#
# Out:
# 1

# %% [markdown]
# - 숫자 7을 출력한다.

# %%
#
# Out:
# 7

# %% [markdown]
# - 마지막 숫자 10을 출력한다.

# %%
#
# Out:
# 10

# %%
#
# Out:
# 10

# %% [markdown]
# - NumPy를 사용하여 기초 통계 함수를 사용해본다.

# %%
#
# Out:
# 5.5

# %% [markdown]
# ## 사칙 연산
# - 이번에는 임의의 수학 점수와 영어 점수를 합산하는 코드를 작성한다.
# - 그런데, List를 연산하면 원하는 결괏값이 나타나지 않는다.
# - 따라서, 리스트를 배열로 변환해야 한다.

# %%
#
# Out:
# [90, 80, 88, 75, 85, 90, 100, 88, 80, 85]

# %%
#

# %% [markdown]
# - 최소 및 최대 값을 구한다.

# %%
#
# Out:
# array([180, 180, 176, 155, 170])

# %%
#
# Out:
# 155

# %%
#
# Out:
# 180

# %% [markdown]
# ## 배열의 생성
# - 배열은 크게 0차원부터 3차원까지로 구성한다.

# %%
#
# Out:
# <class 'numpy.ndarray'>
# ()

# %%
# 1차원
# Out:
# <class 'numpy.ndarray'>
# (3,)

# %%
# 2차원
# Out:
# <class 'numpy.ndarray'>
# (2, 3)

# %%
# 3차원
# Out:
# <class 'numpy.ndarray'>
# (2, 2, 3)

# %%
#
# Out:
# [[1 2 3 4]]
# shape of array : (1, 4)
